# %%
# %%writefile app.py
import openai
import streamlit as st


col1, col2, col3, col4, col5 = st.columns(5)
with col1:
    # Add custom CSS style to position the button at the top-left corner
    st.markdown(
        """
        <style>
        .custom-button {
            position: absolute;
            top: 10px;
            left: 10px;
        }
        </style>
        """,
        unsafe_allow_html=True
    )

    # Use st.empty() to create an empty container at the top-left corner
    button_container = st.empty()

    # Button to be placed at the top-left corner
    if button_container.button("Contact us", key="costom_button"):


        st.write("khadidja_mek@hotmail.fr")
        


with col2:
    # Add custom CSS style to position the button at the top-left and in the middle
    st.markdown(
        """
        <style>
        .custom-button {
            position: absolute;
            top: 50%;
            left: 10px;
            transform: translateY(-50%);
        }
        </style>
        """,
        unsafe_allow_html=True
    )

    # Use st.empty() to create an empty container at the top-left and in the middle
    button_container = st.empty()

    # Button to be placed at the top-left and in the middle
    if button_container.button("Author", key="my_custom"):
       st.write('Khadidja')


with col3:
    # Add custom CSS style to position the button at the top-left corner
    st.markdown(
        """
        <style>
        .custom-button {
            position: absolute;
            top: 10px;
            left: 10px;
        }
        </style>
        """,
        unsafe_allow_html=True
    )

    # Use st.empty() to create an empty container at the top-left corner
    button_container = st.empty()

    if button_container.button("Satisfaction", key="custom"):
        st.selectbox("Rate your satisfaction (1-5)", range(1, 6))

with col4:
    # Add custom CSS style to position the button at the top-left corner
    st.markdown(
        """
        <style>
        .custom-button {
            position: absolute;
            top: 10px;
            left: 10px;
        }
        </style>
        """,
        unsafe_allow_html=True
    )

    # Use st.empty() to create an empty container at the top-left corner
    button_container = st.empty()
    if button_container.button("Profession", key="Data"):
        st.write("Machine learning engineer")

with col5:
    # Add custom CSS style to position the button at the top-left corner
    st.markdown(
        """
        <style>
        .custom-button {
            position: absolute;
            top: 10px;
            left: 10px;
        }
        </style>
        """,
        unsafe_allow_html=True
    )

    # Use st.empty() to create an empty container at the top-left corner
    button_container = st.empty()
    if button_container.button("About us", key="info"):
        st.write("QualityCoder")
st.sidebar.markdown("<h1 style='text-align: center; font-size: 36px;'>QualityCoder</h1>", unsafe_allow_html=True)
# Display a logo in the sidebar

# Sidebar instructions for the code evaluation application
st.sidebar.header("Welcome to QualityCoder!")
st.sidebar.write("🌟 Begin your journey towards better code: 🌟")

st.sidebar.write("""
- Enter Your Code: Paste your code in the 'Enter your code' field.
- Specify Instructions: Detail how you intended the code to be written in the 'Enter the instructions' field.

- Evaluate Code: Click 'Evaluate Code' to get an assessment of your code.
- View Results: Scroll down to see the evaluation results and insights.
""")

st.sidebar.write("Happy coding! Enhance your code quality with insightful evaluations! 🚀")

# Set up your OpenAI API key
openai.api_key = ''#put  your api key here

# Streamlit app title
st.title("Code Evaluation Tool")
#st.image("/content/code_eva.png")

# Get user input for the instructions on how the code should be written
description = st.text_area("**Enter the instructions on how the code should be written:**", height=150)

# Get user input for the code
user_input = st.text_area("**Enter your code:**", height=250)



# Button to evaluate the code
if st.button('Evaluate Code'):
    if user_input and description:
        # Using the chat completions endpoint
        response = openai.ChatCompletion.create(
            model="gpt-3.5-turbo",
            messages=[
                {"role": "system", "content": "You are a helpful assistant."},
                {"role": "user", "content": f"""
                    Evaluate the following code based on how well it aligns with the provided instructions.
                    Code:
                    {user_input}

                    Instructions for Writing the Code:
                    {description}

                    Evaluation Criteria:
                    - Firt the headings must be in bold with big font size to make the difference between the headings and the text.
                    - Performance: Analyze the code’s execution efficiency.
                    - Readability: Assess readability based on naming conventions, indentation, and commenting.
                    - Modularity: Examine if the code is organized into well-defined modules.
                    - Maintainability: Determine the ease of modifying and extending the code.
                    - Preprocessing:reduce 10% if preprocessing is missing
                    - Training the model or load pretraind model. reduce 10% if training is missing
                    - Splitting the data. reduce 10% if splliting is missing
                    - Testing the model.  reduce 10% if testing is missing

                    - Portability: Test on different platforms and environments.
                    - Is the code clean?
                    - Plagiarism
                    - Testability: Analyze the ease of testing the code.
                    - Usability (for user-facing components): Assess ease of use and accessibility.
                    - Is this code solving the task description? And if not, how close is this code to the task description?
                    - The evaluation can be up to 1000 words.
                    - I need make sure that the code contains the main concepts like:
                    -You must give a score at the end for the code out of 100  and the score its really important so it must be in bold.
                    - Note:its realy important to write a Note at the end with the correction if there is any mistake its a must.the note note should be in a box using html
                    -follow the example bellow for the outputs:
                     The code is well-structured, efficient, and adheres to readability standards, but lacks comprehensive comments and clear separation of concerns for better maintainability.
                     While modular to an extent, it needs more defined sections for machine learning tasks like preprocessing, data splitting, training, and testing.
                     Its performance is commendable, but the scalability and testability aspects require enhancement.
                     The user interface is user-friendly, but the code doesn't fully align with the task description, as it focuses more on user validation in a recommendation system and misses some key machine learning pipeline components.
                      •	Score: 85/100
                      Note: The code could be further improved by addressing the following points:
                      •	Separate the code into functions or classes for better modularity.
                      •	Remove redundant or unused imports.
                      •	Provide more comments to explain the code and increase readability.
                      •	Improve error handling and error messages to enhance usability.
                      •	Consider using a dedicated CSS file for styling instead of inline styles in Markdown.
                      •	Overall, the code is well-structured and functional, but there is room for improvement in terms of maintainability, testability, and readability.
                      Please find the corrected code below:
                          import streamlit as st
                          import pandas as pd
                          import numpy as np
                          import matplotlib.pyplot as plt
                          def main():
                          st.set_page_config(layout="wide")
                          show_help_menu = st.sidebar.button('Help Menu')
                    -you must really really write the code again with correction in python luanguage and put it inside a box please using .
                """}
            ]
        )

        # Extracting the generated text from the response
        generated_text = response.choices[0].message.content

        # Displaying the evaluation result
        st.write("Evaluation Result:")
        st.write(generated_text)
        
    else:
        st.error("Please enter both the code and the instructions.")
# Out:
# Overwriting app.py
